# %% [markdown]
# # Part 2: Basic queries - exercises
#
# ### Goals
# * To make simple requests to SRU
# * To display content of a record
#
# ### How to use it
# #### SRU servers
# * https://swisscovery.slsp.ch/view/sru/41SLSP_NETWORK?version=1.2&operation=explain
# * https://renouvaud.primo.exlibrisgroup.com/view/sru/41BCULAUSA_NETWORK?version=1.2&operation=explain
# * https://www.sudoc.abes.fr/cbs/sru/?operation=explain&version=1.1
#
# #### Documentation
# * https://slsp.ch/fr/metadonnees/
# * https://developers.exlibrisgroup.com/alma/integrations/sru/
# * https://knowledge.exlibrisgroup.com/Alma/Product_Documentation/Alma_Online_Help_(Francais)/130Int%C3%A9grations_avec_des_syst%C3%A8mes_externes/030Gestion_des_ressources/170Recherche_SRU%2F%2FSRW
# * https://abes.fr/wp-content/uploads/2023/05/guide-utilisation-service-sru-catalogue-sudoc.pdf

# %%
# Import libraries
import requests
from lxml import etree

# An XML parser is required to enable pretty printing to work when updating XML.
parser = etree.XMLParser(remove_blank_text=True, remove_comments=True, ns_clean=True)

# Namespaces shortcuts
ns = {
    "srw": "http://www.loc.gov/zing/srw/",
    "marc": "http://www.loc.gov/MARC21/slim"
}

# %%
# Build simple request
# Idea is to find 2 records with "Python" in the title

params = {
    'version': '1.2',
    'operation': 'searchRetrieve',
    'query': 'alma.title=arbres',
    'maximumRecords': '5'
}

url = 'https://swisscovery.ch/view/sru/41SLSP_NETWORK'

r = requests.get(url, params=params)
print(r.text)
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?><searchRetrieveResponse xmlns="http://www.loc.gov/zing/srw/">
#   <version>1.2</version>
#   <numberOfRecords>3191</numberOfRecords>
#   <records>
#     <record>
#       <recordSchema>marcxml</recordSchema>
#       <recordPacking>xml</recordPacking>
#       <recordData>
#         <record xmlns="http://www.loc.gov/MARC21/slim">
#           <leader>01043nam a22002892c 4500</leader>
#           <controlfield tag="001">991018314729705501</controlfield>
#           <controlfield tag="005">20201222201316.0</controlfield>
#           <controlfield tag="008">130826r19671788xxu||||| |||| 00| ||eng d</controlfield>
#           <datafield ind1=" " ind2=" " tag="035">
#             <subfield code="a">(swissbib)117972746-41slsp_network</subfield>
#           </datafield>
#           <datafield ind1=" " ind2=" " tag="035">
#             <subfield code="a">117972746</subfield>
#             <subfield code="9">ExL</subfield>
#           </datafield>
#           <datafield ind1=" " ind2=" " tag="035">
#             <subfield code="a">(RERO)R007454485-41slsp</subfield>
#           </datafield>
#           <datafield ind1=" " ind2=" " tag="040">
#             <subfield code="a">RERO gevcjb</subfield>
#             <subfield code="d">CH-ZuSLS</subfield>
#           </datafield>
#           <datafield ind1=" " ind2="7" tag="072">
#             <subfield code="a">bo</subfield>
#             <subfield code="2">rero</subfield>
#           </datafield>
#           <datafield ind1="1" ind2=" " tag="100">
#             <subfield code="a">Marshall, Humphrey</subfield>
#             <subfield code="d">1722-1801</subfield>
#             <subfield code="0">(IDREF)073761664</subfield>
#             <subfield code="4">cre</subfield>
#           </datafield>
#           <datafield ind1="1" ind2="0" tag="245">
#             <subfield code="a">... Catalogue alphabétique des arbres et arbrisseaux</subfield>
#             <subfield code="c">Humphry Marshall ; trad. de l'anglois par M. Lézermes ; introd. by Joseph Ewan</subfield>
#           </datafield>
#           <datafield ind1=" " ind2=" " tag="250">
#             <subfield code="a">Reprint</subfield>
#           </datafield>
#           <datafield ind1=" " ind2="1" tag="264">
#             <subfield code="a">New York</subfield>
#             <subfield code="b">[éditeur non identifié]</subfield>
#             <subfield code="c">1967</subfield>
#           </datafield>
#           <datafield ind1=" " ind2=" " tag="300">
#             <subfield code="a">1 vol.</subfield>
#             <subfield code="c">8°</subfield>
#           </datafield>
#           <datafield ind1=" " ind2=" " tag="336">
#             <subfield code="b">txt</subfield>
#             <subfield code="2">rdacontent</subfield>
#           </datafield>
#           <datafield ind1=" " ind2=" " tag="337">
#             <subfield code="b">n</subfield>
#             <subfield code="2">rdamedia</subfield>
#           </datafield>
#           <datafield ind1=" " ind2=" " tag="338">
#             <subfield code="b">nc</subfield>
#             <subfield code="2">rdacarrier</subfield>
#           </datafield>
#           <datafield ind1="1" ind2=" " tag="490">
#             <subfield code="a">Classica botanica americana</subfield>
#             <subfield code="v">vol. 1</subfield>
#           </datafield>
#           <datafield ind1=" " ind2=" " tag="534">
#             <subfield code="p">Reprod. de l'éd. de:</subfield>
#             <subfield code="c">Paris, 1788</subfield>
#           </datafield>
#           <datafield ind1="1" ind2=" " tag="700">
#             <subfield code="a">Lézermes, M</subfield>
#             <subfield code="0">(RERO)A023625137</subfield>
#           </datafield>
#           <datafield ind1="1" ind2=" " tag="700">
#             <subfield code="a">Ewan, Joseph</subfield>
#             <subfield code="0">(RERO)A003226808</subfield>
#           </datafield>
#           <datafield ind1=" " ind2=" " tag="830">
#             <subfield code="a">Classica botanica Americana</subfield>
#             <subfield code="v">1</subfield>
#             <subfield code="w">(RERO)R003904490-41slsp</subfield>
#           </datafield>
#           <datafield ind1="0" ind2="1" tag="852">
#             <subfield code="a">41SLSP_VGE</subfield>
#             <subfield code="6">991008385739705524</subfield>
#             <subfield code="9">P</subfield>
#           </datafield>
#           <datafield ind1=" " ind2=" " tag="900">
#             <subfield code="a">REROnoselfmerge</subfield>
#           </datafield>
#         </record>
#       </recordData>
#       <recordIdentifier>991018314729705501</recordIdentifier>
#       <recordPosition>1</recordPosition>
#     </record>
#     <record>
#       <recordSchema>marcxml</recordSchema>
#       <recordPacking>xml</recordPacking>
#       <recordData>
#         <record xmlns="http://www.loc.gov/MARC21/slim">
#           <leader>00713nam a2200169 c 4500</leader>
#           <controlfield tag="001">991129365939705501</controlfield>
#           <controlfield tag="005">20241218231537.0</controlfield>
#           <controlfield tag="008">000210s1883    fr            00| | fre^^</controlfield>
#           <datafield ind1=" " ind2=" " tag="035">
#             <subfield code="a">(swissbib)152817182-41slsp_network</subfield>
#           </datafield>
#           <datafield ind1=" " ind2=" " tag="035">
#             <subfield code="a">152817182</subfield>
#             <subfield code="9">ExL</subfield>
#           </datafield>
#           <datafield ind1=" " ind2=" " tag="035">
#             <subfield code="a">(NEBIS)003851212EBI01</subfield>
#           </datafield>
#           <datafield ind1=" " ind2=" " tag="040">
#             <subfield code="a">ETH-FOR</subfield>
#             <subfield code="d">CH-ZuSLS</subfield>
#           </datafield>
#           <datafield ind1="0" ind2="0" tag="245">
#             <subfield code="a">&lt;&lt;L&gt;&gt;'art de planter</subfield>
#             <subfield code="b">plantations en général - plantations en butte : traité pratique sur l'art d'élever en pépinière et de planter à demeure les arbres forestiers - fruitiers - d'agrément</subfield>
#             <subfield code="c">par le Baron H.-E. de Manteuffel</subfield>
#           </datafield>
#           <datafield ind1=" " ind2=" " tag="250">
#             <subfield code="a">3ème éd.</subfield>
#           </datafield>
#           <datafield ind1=" " ind2="1" tag="264">
#             <subfield code="a">Paris</subfield>
#             <subfield code="b">Rothschild</subfield>
#             <subfield code="c">1883</subfield>
#           </datafield>
#           <datafield ind1=" " ind2=" " tag="300">
#             <subfield code="a">256 S.</subfield>
#             <subfield code="b">Ill.</subfield>
#           </datafield>
#           <datafield ind1="1" ind2=" " tag="700">
#             <subfield code="a">Manteuffel, Hans Ernst &lt;&lt;von&gt;&gt;</subfield>
#             <subfield code="d">1799-1872</subfield>
#             <subfield code="0">(DE-588)12276434X</subfield>
#           </datafield>
#           <datafield ind1="0" ind2="1" tag="852">
#             <subfield code="a">41SLSP_ETH</subfield>
#             <subfield code="6">990038512120205503</subfield>
#             <subfield code="9">P</subfield>
#           </datafield>
#         </record>
#       </recordData>
#       <recordIdentifier>991129365939705501</recordIdentifier>
#       <recordPosition>2</recordPosition>
#     </record>
#     <record>
#       <recordSchema>marcxml</recordSchema>
#       <recordPacking>xml</recordPacking>
#       <recordData>
#         <record xmlns="http://www.loc.gov/MARC21/slim">
#           <leader>00590nam a2200157 c 4500</leader>
#           <controlfield tag="001">991007349719705501</controlfield>
#           <controlfield tag="005">20241128135153.0</controlfield>
#           <controlfield tag="008">000301s1865    fr            00| | fre^^</controlfield>
#           <datafield ind1=" " ind2=" " tag="035">
#             <subfield code="a">(swissbib)152890319-41slsp_network</subfield>
#           </datafield>
#           <datafield ind1=" " ind2=" " tag="035">
#             <subfield code="a">152890319</subfield>
#             <subfield code="9">ExL</subfield>
#           </datafield>
#           <datafield ind1=" " ind2=" " tag="035">
#             <subfield code="a">(NEBIS)003860168EBI01</subfield>
#           </datafield>
#           <datafield ind1=" " ind2=" " tag="040">
#             <subfield code="a">ETH-FOR</subfield>
#             <subfield code="d">CH-ZuSLS</subfield>
#           </datafield>
#           <datafield ind1="0" ind2="0" tag="245">
#             <subfield code="a">&lt;&lt;L&gt;&gt;'élagage des arbres</subfield>
#             <subfield code="b">traité pratique de l'art de diriger les arbres forestiers et d'alignement, d'activer leur croissance et d'augmenter leur valeur</subfield>
#             <subfield code="c">par le Cte A. Des Cars</subfield>
#           </datafield>
#           <datafield ind1=" " ind2="1" tag="264">
#             <subfield code="a">Paris</subfield>
#             <subfield code="b">J. Rothschild</subfield>
#             <subfield code="c">1865</subfield>
#           </datafield>
#           <datafield ind1=" " ind2=" " tag="300">
#             <subfield code="a">151 S.</subfield>
#             <subfield code="b">Ill.</subfield>
#           </datafield>
#           <datafield ind1="1" ind2=" " tag="700">
#             <subfield code="a">Des Cars, A.</subfield>
#           </datafield>
#           <datafield ind1="0" ind2="1" tag="852">
#             <subfield code="a">41SLSP_ETH</subfield>
#             <subfield code="6">990038601680205503</subfield>
#             <subfield code="9">P</subfield>
#           </datafield>
#         </record>
#       </recordData>
#       <recordIdentifier>991007349719705501</recordIdentifier>
#       <recordPosition>3</recordPosition>
#     </record>
#     <record>
#       <recordSchema>marcxml</recordSchema>
#       <recordPacking>xml</recordPacking>
#       <recordData>
#         <record xmlns="http://www.loc.gov/MARC21/slim">
#           <leader>00891naa a2200253 c 4500</leader>
#           <controlfield tag="001">991115553749705501</controlfield>
#           <controlfield tag="005">20211101193724.0</controlfield>
#           <controlfield tag="008">020215s1965    sz ||||| |||| 00| ||fre d</controlfield>
#           <datafield ind1=" " ind2=" " tag="035">
#             <subfield code="a">(swissbib)097557498-41slsp_network</subfield>
#           </datafield>
#           <datafield ind1=" " ind2=" " tag="035">
#             <subfield code="a">097557498</subfield>
#             <subfield code="9">ExL</subfield>
#           </datafield>
#           <datafield ind1=" " ind2=" " tag="035">
#             <subfield code="a">(RERO)R003152623-41slsp</subfield>
#           </datafield>
#           <datafield ind1=" " ind2=" " tag="040">
#             <subfield code="a">RERO gevbpu</subfield>
#             <subfield code="d">CH-ZuSLS</subfield>
#           </datafield>
#           <datafield ind1=" " ind2=" " tag="044">
#             <subfield code="a">sz</subfield>
#             <subfield code="c">ch-ge</subfield>
#           </datafield>
#           <datafield ind1="0" ind2=" " tag="045">
#             <subfield code="b">d 19650619</subfield>
#           </datafield>
#           <datafield ind1=" " ind2="7" tag="072">
#             <subfield code="a">fr</subfield>
#             <subfield code="2">rero</subfield>
#           </datafield>
#           <datafield ind1="1" ind2=" " tag="100">
#             <subfield code="a">Vuilleumier, Jean</subfield>
#             <subfield code="d">1934-2012</subfield>
#             <subfield code="0">(IDREF)027190803</subfield>
#             <subfield code="4">cre</subfield>
#           </datafield>
#           <datafield ind1="1" ind2="0" tag="245">
#             <subfield code="a">"Au-delà du fleuve et sous les arbres" d'Ernest Hemingway</subfield>
#             <subfield code="c">Jean Vuilleumier</subfield>
#           </datafield>
#           <datafield ind1=" " ind2=" " tag="336">
#             <subfield code="b">txt</subfield>
#             <subfield code="2">rdacontent</subfield>
#           </datafield>
#           <datafield ind1=" " ind2=" " tag="337">
#             <subfield code="b">n</subfield>
#             <subfield code="2">rdamedia</subfield>
#           </datafield>
#           <datafield ind1=" " ind2=" " tag="338">
#             <subfield code="b">nc</subfield>
#             <subfield code="2">rdacarrier</subfield>
#           </datafield>
#           <datafield ind1=" " ind2=" " tag="500">
#             <subfield code="a">Fait partie d'une chronique littéraire intitulée "Le roman de la semaine"</subfield>
#           </datafield>
#           <datafield ind1=" " ind2=" " tag="580">
#             <subfield code="a">In: Tribune de Genève. - Genève. - 19-20 juin 1965, p. V</subfield>
#           </datafield>
#           <datafield ind1="0" ind2=" " tag="773">
#             <subfield code="t">Tribune de Genève</subfield>
#             <subfield code="g">1965/06/19</subfield>
#             <subfield code="g">yr:1965</subfield>
#           </datafield>
#           <datafield ind1="0" ind2="1" tag="852">
#             <subfield code="a">41SLSP_VGE</subfield>
#             <subfield code="6">991009066529705524</subfield>
#             <subfield code="9">P</subfield>
#           </datafield>
#           <datafield ind1=" " ind2=" " tag="900">
#             <subfield code="a">REROnoselfmerge</subfield>
#           </datafield>
#         </record>
#       </recordData>
#       <recordIdentifier>991115553749705501</recordIdentifier>
#       <recordPosition>4</recordPosition>
#     </record>
#     <record>
#       <recordSchema>marcxml</recordSchema>
#       <recordPacking>xml</recordPacking>
#       <recordData>
#         <record xmlns="http://www.loc.gov/MARC21/slim">
#           <leader>01483nam a2200385uc 4500</leader>
#           <controlfield tag="001">991129306629705501</controlfield>
#           <controlfield tag="005">20230228191842.0</controlfield>
#           <controlfield tag="008">201012s1988    fr ||||| |||| 00| ||fre d</controlfield>
#           <datafield ind1=" " ind2=" " tag="020">
#             <subfield code="a">2706809639</subfield>
#           </datafield>
#           <datafield ind1="7" ind2=" " tag="024">
#             <subfield code="a">http://catalogue.bnf.fr/ark:/12148/cb34950577g</subfield>
#             <subfield code="2">uri</subfield>
#           </datafield>
#           <datafield ind1=" " ind2=" " tag="035">
#             <subfield code="a">(swissbib)234184981-41slsp_network</subfield>
#           </datafield>
#           <datafield ind1=" " ind2=" " tag="035">
#             <subfield code="a">234184981</subfield>
#             <subfield code="9">ExL</subfield>
#           </datafield>
#           <datafield ind1=" " ind2=" " tag="035">
#             <subfield code="a">(IDSBB)000672255DSV01</subfield>
#           </datafield>
#           <datafield ind1=" " ind2=" " tag="035">
#             <subfield code="a">(RERO)0984890-41slsp</subfield>
#           </datafield>
#           <datafield ind1=" " ind2=" " tag="040">
#             <subfield code="a">SzZuIDS BS/BE B470</subfield>
#             <subfield code="b">ger</subfield>
#             <subfield code="e">kids</subfield>
#             <subfield code="d">CH-ZuSLS</subfield>
#           </datafield>
#           <datafield ind1=" " ind2="7" tag="072">
#             <subfield code="a">et</subfield>
#             <subfield code="2">SzZuIDS BS/BE</subfield>
#           </datafield>
#           <datafield ind1=" " ind2="7" tag="072">
#             <subfield code="a">et</subfield>
#             <subfield code="2">rero</subfield>
#           </datafield>
#           <datafield ind1="0" ind2="0" tag="245">
#             <subfield code="a">"Aux temps où arbres et plantes disaient des choses"</subfield>
#             <subfield code="c">sous la dir. de Hartmut O. Rotermund ; avec la collab. de Jean-Pierre Berthon, Laurence Caillet, François Macé</subfield>
#           </datafield>
#           <datafield ind1=" " ind2="1" tag="264">
#             <subfield code="c">1988</subfield>
#           </datafield>
#           <datafield ind1=" " ind2=" " tag="300">
#             <subfield code="a">246 S.</subfield>
#             <subfield code="c">24 cm</subfield>
#           </datafield>
#           <datafield ind1=" " ind2=" " tag="336">
#             <subfield code="b">txt</subfield>
#             <subfield code="2">rdacontent</subfield>
#           </datafield>
#           <datafield ind1=" " ind2=" " tag="337">
#             <subfield code="b">n</subfield>
#             <subfield code="2">rdamedia</subfield>
#           </datafield>
#           <datafield ind1=" " ind2=" " tag="338">
#             <subfield code="b">nc</subfield>
#             <subfield code="2">rdacarrier</subfield>
#           </datafield>
#           <datafield ind1="1" ind2=" " tag="490">
#             <subfield code="a">Religions, croyances et traditions populaires du Japon</subfield>
#             <subfield code="v">1</subfield>
#           </datafield>
#           <datafield ind1=" " ind2="7" tag="650">
#             <subfield code="a">Nature</subfield>
#             <subfield code="0">(IDREF)027257002</subfield>
#             <subfield code="2">idref</subfield>
#           </datafield>
#           <datafield ind1=" " ind2="7" tag="650">
#             <subfield code="a">Religion populaire</subfield>
#             <subfield code="0">(IDREF)027242455</subfield>
#             <subfield code="2">idref</subfield>
#           </datafield>
#           <datafield ind1=" " ind2="7" tag="650">
#             <subfield code="a">esprits (êtres spirituels)</subfield>
#             <subfield code="0">(RERO)A010080287</subfield>
#             <subfield code="2">rerovoc</subfield>
#           </datafield>
#           <datafield ind1=" " ind2="7" tag="650">
#             <subfield code="a">Dieux</subfield>
#             <subfield code="0">(IDREF)027661377</subfield>
#             <subfield code="2">idref</subfield>
#           </datafield>
#           <datafield ind1=" " ind2="7" tag="651">
#             <subfield code="a">Japon</subfield>
#             <subfield code="0">(IDREF)027262162</subfield>
#             <subfield code="2">idref</subfield>
#           </datafield>
#           <datafield ind1=" " ind2="7" tag="655">
#             <subfield code="a">Anthologies</subfield>
#             <subfield code="0">(IDREF)027269493</subfield>
#             <subfield code="2">idref</subfield>
#           </datafield>
#           <datafield ind1="1" ind2=" " tag="700">
#             <subfield code="a">Caillet, Laurence</subfield>
#           </datafield>
#           <datafield ind1="1" ind2=" " tag="700">
#             <subfield code="a">Macé, François</subfield>
#           </datafield>
#           <datafield ind1="1" ind2=" " tag="700">
#             <subfield code="a">Berthon, Jean-Pierre</subfield>
#             <subfield code="d">19..-....</subfield>
#             <subfield code="0">(IDREF)029185874</subfield>
#           </datafield>
#           <datafield ind1=" " ind2=" " tag="830">
#             <subfield code="a">Religions, croyances et traditions populaires du Japon</subfield>
#             <subfield code="v">1</subfield>
#             <subfield code="w">(IDSBB)000672228DSV01</subfield>
#           </datafield>
#           <datafield ind1="0" ind2="1" tag="852">
#             <subfield code="a">41SLSP_UGE</subfield>
#             <subfield code="6">991000533389705502</subfield>
#             <subfield code="9">P</subfield>
#           </datafield>
#           <datafield ind1="0" ind2="1" tag="852">
#             <subfield code="a">41SLSP_UBE</subfield>
#             <subfield code="6">99116766221405511</subfield>
#             <subfield code="9">P</subfield>
#           </datafield>
#           <datafield ind1="0" ind2="1" tag="852">
#             <subfield code="a">41SLSP_BCUFR</subfield>
#             <subfield code="6">991004052159705509</subfield>
#             <subfield code="9">P</subfield>
#           </datafield>
#           <datafield ind1=" " ind2=" " tag="900">
#             <subfield code="a">REROnoselfmerge</subfield>
#           </datafield>
#         </record>
#       </recordData>
#       <recordIdentifier>991129306629705501</recordIdentifier>
#       <recordPosition>5</recordPosition>
#     </record>
#   </records>
#   <nextRecordPosition>6</nextRecordPosition>
#   <extraResponseData xmlns:xb="http://www.exlibris.com/repository/search/xmlbeans/">
#     <xb:exact>true</xb:exact>
#     <xb:responseDate>2025-09-01T15:41:58+0200</xb:responseDate>
#   </extraResponseData>
# </searchRetrieveResponse>

# %%
# Display 245a
xml = etree.fromstring(r.content)
f245s = xml.findall('.//marc:datafield[@tag="245"]/marc:subfield[@code="a"]', namespaces=ns)
for f245 in f245s:
    print(f245.text)
# Out:
# ... Catalogue alphabétique des arbres et arbrisseaux
# <<L>>'art de planter
# <<L>>'élagage des arbres
# "Au-delà du fleuve et sous les arbres" d'Ernest Hemingway
# "Aux temps où arbres et plantes disaient des choses"

# %% [markdown]
# ### Some simple requests
# 1. Find 10 documents of Slatkine publisher
# 2. Build a function to display titles in the folowing way: `<245a> (<100a>), <264c>` (you can choose other format)
# 3. Find a document of 2020 with python in the title
# 4. Try other SRU servers
