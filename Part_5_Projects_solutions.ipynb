# %% [markdown]
# # Some idea solutions about the projects of part 5

# %%
# Import libraries
from almasru.client import SruClient, SruRecord, IzSruRecord, SruRequest
from almasru.utils import check_removable_records, analyse_records
from almasru import config_log

import pandas as pd
import numpy as np
from typing import Tuple, Dict, List, Set, Optional

# Config logs
config_log()

# %% [markdown]
# ## Part 5: projects - Fetch analytical records

# %%
mms_id = '990009912310205526'
zone = '41SLSP_RZH'
SruClient.set_base_url(f'https://swisscovery.ch/view/sru/{zone}')
rec = IzSruRecord(mms_id)
iz_analytical = rec.get_child_analytical_records()
print('IZ RZH: ', len(iz_analytical))

mms_id = rec.get_nz_mms_id()
zone = '41SLSP_NETWORK'
SruClient.set_base_url(f'https://swisscovery.ch/view/sru/{zone}')
rec = SruRecord(mms_id)
nz_analytical = rec.get_child_analytical_records()
print('NZ: ', len(nz_analytical))
# Out:
# 2025-09-09 06:23:46,455 - INFO - SRU data fetched: https://swisscovery.ch/view/sru/41SLSP_RZH?query=alma.mms_id%3D990009912310205526&version=1.2&operation=searchRetrieve&startRecord=1&maximumRecords=10
# 2025-09-09 06:23:46,461 - INFO - Records 1 - 1 / 1, "alma.mms_id=990009912310205526": 1
# 2025-09-09 06:23:49,175 - INFO - SRU data fetched: https://swisscovery.ch/view/sru/41SLSP_RZH?query=alma.other_system_number%3D%28NEBIS%29000991231EBI01&version=1.2&operation=searchRetrieve&startRecord=1&maximumRecords=50
# 2025-09-09 06:23:49,187 - INFO - Records 1 - 21 / 21, "alma.other_system_number=(NEBIS)000991231EBI01": 21
# 2025-09-09 06:23:49,897 - INFO - SRU data fetched: https://swisscovery.ch/view/sru/41SLSP_RZH?query=alma.other_system_number%3D991124328919705501&version=1.2&operation=searchRetrieve&startRecord=1&maximumRecords=50
# 2025-09-09 06:23:49,903 - WARNING - No record found for query alma.other_system_number=991124328919705501
# 2025-09-09 06:23:51,073 - INFO - SRU data fetched: https://swisscovery.ch/view/sru/41SLSP_RZH?query=alma.other_system_number%3D%3D%28swissbib%29217572502-41slsp_network&version=1.2&operation=searchRetrieve&startRecord=1&maximumRecords=50
# 2025-09-09 06:23:51,077 - INFO - Records 1 - 1 / 1, "alma.other_system_number==(swissbib)217572502-41slsp_network": 1
# 2025-09-09 06:23:51,715 - INFO - SRU data fetched: https://swisscovery.ch/view/sru/41SLSP_RZH?query=alma.other_system_number%3D990009912310205526&version=1.2&operation=searchRetrieve&startRecord=1&maximumRecords=50
# 2025-09-09 06:23:51,721 - WARNING - No record found for query alma.other_system_number=990009912310205526
# 2025-09-09 06:23:52,694 - INFO - SRU data fetched: https://swisscovery.ch/view/sru/41SLSP_RZH?query=alma.other_system_number%3D%28IDSBB%29000092204DSV01&version=1.2&operation=searchRetrieve&startRecord=1&maximumRecords=50
# 2025-09-09 06:23:52,701 - INFO - Records 1 - 1 / 1, "alma.other_system_number=(IDSBB)000092204DSV01": 1
# IZ RZH:  20
# 2025-09-09 06:23:53,491 - INFO - SRU data fetched: https://swisscovery.ch/view/sru/41SLSP_NETWORK?query=alma.mms_id%3D991124328919705501&version=1.2&operation=searchRetrieve&startRecord=1&maximumRecords=10
# 2025-09-09 06:23:53,495 - INFO - Records 1 - 1 / 1, "alma.mms_id=991124328919705501": 1
# 2025-09-09 06:23:55,955 - INFO - SRU data fetched: https://swisscovery.ch/view/sru/41SLSP_NETWORK?query=alma.other_system_number%3D%28NEBIS%29000991231EBI01&version=1.2&operation=searchRetrieve&startRecord=1&maximumRecords=50
# 2025-09-09 06:23:55,962 - INFO - Records 1 - 22 / 22, "alma.other_system_number=(NEBIS)000991231EBI01": 22
# 2025-09-09 06:23:57,156 - INFO - SRU data fetched: https://swisscovery.ch/view/sru/41SLSP_NETWORK?query=alma.other_system_number%3D%3D%28swissbib%29217572502-41slsp_network&version=1.2&operation=searchRetrieve&startRecord=1&maximumRecords=50
# 2025-09-09 06:23:57,163 - INFO - Records 1 - 1 / 1, "alma.other_system_number==(swissbib)217572502-41slsp_network": 1
# 2025-09-09 06:23:57,824 - INFO - SRU data fetched: https://swisscovery.ch/view/sru/41SLSP_NETWORK?query=alma.other_system_number%3D991124328919705501&version=1.2&operation=searchRetrieve&startRecord=1&maximumRecords=50
# 2025-09-09 06:23:57,830 - WARNING - No record found for query alma.other_system_number=991124328919705501
# 2025-09-09 06:23:59,202 - INFO - SRU data fetched: https://swisscovery.ch/view/sru/41SLSP_NETWORK?query=alma.other_system_number%3D%28IDSBB%29000092204DSV01&version=1.2&operation=searchRetrieve&startRecord=1&maximumRecords=50
# 2025-09-09 06:23:59,219 - INFO - Records 1 - 4 / 4, "alma.other_system_number=(IDSBB)000092204DSV01": 4
# NZ:  22

# %% [markdown]
# ## Part 5: projects - Check removable records

# %%
mms_ids_to_check = [
    '991171228773105501', '991153648929705501', '991095338679705501',
    '991108597099705501', '991107511699705501', '991132863209705501',
    '991152338469705501', '991171357508305501', '991126902329705501',
    '991171337525005501', '991094843849705501', '991093934809705501',
    '991154177219705501', '991156446029705501', '991170675750105501',
    '991006488319705501', '991153029939705501', '991149212459705501',
    '991170647161305501', '991171866808105501', '991055945739705501',
]
df = check_removable_records(mms_ids_to_check)
df
# Out:
# 2025-09-09 06:24:00,029 - INFO - SRU data fetched: https://swisscovery.ch/view/sru/41SLSP_NETWORK?query=alma.mms_id%3D
501', base_url='https://swisscovery.ch/view/sru/41SLSP_NETWORK'): record not used in the IZs
# 2025-09-09 06:24:18,977 - INFO - Processed: 1 / remaining: 19 / current: SruRecord('991153648929705501', base_url='https://swisscovery.ch/view/sru/41SLSP_NETWORK')
# 2025-09-09 06:24:18,980 - INFO - SruRecord('991153648929705501', base_url='https://swisscovery.ch/view/sru/41SLSP_NETWORK'): record not used in the IZs
# 2025-09-09 06:24:20,327 - INFO - SRU data fetched: https://swisscovery.ch/view/sru/41SLSP_NETWORK?query=alma.other_system_number%3D991153648929705501&version=1.2&operation=searchRetrieve&startRecord=1&maximumRecords=50
# 2025-09-09 06:24:20,333 - WARNING - No record found for query alma.other_system_number=991153648929705501
# 2025-09-09 06:24:21,706 - INFO - SRU data fetched: https://swisscovery.ch/view/sru/41SLSP_NETWORK?query=alma.other_system_number%3D%3D%28swissbib%29175996237-41slsp_network&version=1.2&operation=searchRetrieve&startRecord=1&maximumRecords=50
# 2025-09-09 06:24:21,712 - INFO - Records 1 - 1 / 1, "alma.other_system_number==(swissbib)175996237-41slsp_network": 1
# 2025-09-09 06:24:23,470 - INFO - SRU data fetched: https://swisscovery.ch/view/sru/41SLSP_NETWORK?query=alma.other_system_number%3D%28NEBIS%29006615750EBI01&version=1.2&operation=searchRetrieve&startRecord=1&maximumRecords=50
# 2025-09-09 06:24:23,474 - INFO - Records 1 - 1 / 1, "alma.other_system_number=(NEBIS)006615750EBI01": 1
# 2025-09-09 06:24:24,445 - INFO - SRU data fetched: https://swisscovery.ch/view/sru/41SLSP_NETWORK?query=alma.standard_number%3D9781405158039&version=1.2&operation=searchRetrieve&startRecord=1&maximumRecords=50
# 2025-09-09 06:24:24,451 - INFO - Records 1 - 1 / 1, "alma.standard_number=9781405158039": 1
# 2025-09-09 06:24:24,454 - INFO - SruRecord('991153648929705501', base_url='https://swisscovery.ch/view/sru/41SLSP_NETWORK'): record not used in the IZs
# 2025-09-09 06:24:24,460 - INFO - Processed: 2 / remaining: 18 / current: SruRecord('991095338679705501', base_url='https://swisscovery.ch/view/sru/41SLSP_NETWORK')
# 2025-09-09 06:24:24,462 - INFO - SruRecord('991095338679705501', base_url='https://swisscovery.ch/view/sru/41SLSP_NETWORK'): record used in IZ: 41SLSP_ETH, 41SLSP_EPF
# 2025-09-09 06:24:24,464 - WARNING - SruRecord('991095338679705501', base_url='https://swisscovery.ch/view/sru/41SLSP_NETWORK') cannot be deleted: record used in IZs: 41SLSP_ETH, 41SLSP_EPF
# 2025-09-09 06:24:24,466 - INFO - SruRecord('991095338679705501', base_url='https://swisscovery.ch/view/sru/41SLSP_NETWORK'): record used in IZ: 41SLSP_ETH, 41SLSP_EPF
# 2025-09-09 06:24:24,471 - INFO - Processed: 3 / remaining: 17 / current: SruRecord('991108597099705501', base_url='https://swisscovery.ch/view/sru/41SLSP_NETWORK')
# 2025-09-09 06:24:24,473 - INFO - SruRecord('991108597099705501', base_url='https://swisscovery.ch/view/sru/41SLSP_NETWORK'): record used in IZ: 41SLSP_SUP
# 2025-09-09 06:24:24,474 - WARNING - SruRecord('991108597099705501', base_url='https://swisscovery.ch/view/sru/41SLSP_NETWORK') cannot be deleted: record used in IZs: 41SLSP_SUP
# 2025-09-09 06:24:24,475 - INFO - SruRecord('991108597099705501', base_url='https://swisscovery.ch/view/sru/41SLSP_NETWORK'): record used in IZ: 41SLSP_SUP
# 2025-09-09 06:24:24,477 - INFO - Processed: 4 / remaining: 16 / current: SruRecord('991107511699705501', base_url='https://swisscovery.ch/view/sru/41SLSP_NETWORK')
# 2025-09-09 06:24:24,479 - INFO - SruRecord('991107511699705501', base_url='https://swisscovery.ch/view/sru/41SLSP_NETWORK'): record used in IZ: 41SLSP_RZH, 41SLSP_VGE, 41SLSP_UBS
# 2025-09-09 06:24:24,481 - WARNING - SruRecord('991107511699705501', base_url='https://swisscovery.ch/view/sru/41SLSP_NETWORK') cannot be deleted: record used in IZs: 41SLSP_RZH, 41SLSP_VGE, 41SLSP_UBS
# 2025-09-09 06:24:24,482 - INFO - SruRecord('991107511699705501', base_url='https://swisscovery.ch/view/sru/41SLSP_NETWORK'): record used in IZ: 41SLSP_RZH, 41SLSP_VGE, 41SLSP_UBS
# 2025-09-09 06:24:24,486 - INFO - Processed: 5 / remaining: 15 / current: SruRecord('991132863209705501', base_url='https://swisscovery.ch/view/sru/41SLSP_NETWORK')
# 2025-09-09 06:24:24,487 - INFO - SruRecord('991132863209705501', base_url='https://swisscovery.ch/view/sru/41SLSP_NETWORK'): record not used in the IZs
# 2025-09-09 06:24:25,184 - INFO - SRU data fetched: https://swisscovery.ch/view/sru/41SLSP_NETWORK?query=alma.other_system_number%3D%3D%28swissbib%29208814434-41slsp_network&version=1.2&operation=searchRetrieve&startRecord=1&maximumRecords=50
# 2025-09-09 06:24:25,198 - INFO - Records 1 - 1 / 1, "alma.other_system_number==(swissbib)208814434-41slsp_network": 1
# 2025-09-09 06:24:25,827 - INFO - SRU data fetched: https://swisscovery.ch/view/sru/41SLSP_NETWORK?query=alma.other_system_number%3D991132863209705501&version=1.2&operation=searchRetrieve&startRecord=1&maximumRecords=50
# 2025-09-09 06:24:25,833 - WARNING - No record found for query alma.other_system_number=991132863209705501
# 2025-09-09 06:24:27,364 - INFO - SRU data fetched: https://swisscovery.ch/view/sru/41SLSP_NETWORK?query=alma.other_system_number%3D%28NEBIS%29011419446EBI01&version=1.2&operation=searchRetrieve&startRecord=1&maximumRecords=50
# 2025-09-09 06:24:27,367 - INFO - Records 1 - 1 / 1, "alma.other_system_number=(NEBIS)011419446EBI01": 1
# 2025-09-09 06:24:28,233 - INFO - SRU data fetched: https://swisscovery.ch/view/sru/41SLSP_NETWORK?query=alma.standard_number%3D818901336X&version=1.2&operation=searchRetrieve&startRecord=1&maximumRecords=50
# 2025-09-09 06:24:28,240 - INFO - Records 1 - 1 / 1, "alma.standard_number=818901336X": 1
# 2025-09-09 06:24:29,342 - INFO - SRU data fetched: https://swisscovery.ch/view/sru/41SLSP_NETWORK?query=alma.standard_number%3D9788189013363&version=1.2&operation=searchRetrieve&startRecord=1&maximumRecords=50
# 2025-09-09 06:24:29,346 - INFO - Records 1 - 1 / 1, "alma.standard_number=9788189013363": 1
# 2025-09-09 06:24:29,348 - INFO - SruRecord('991132863209705501', base_url='https://swisscovery.ch/view/sru/41SLSP_NETWORK'): record not used in the IZs
# 2025-09-09 06:24:29,351 - INFO - Processed: 6 / remaining: 14 / current: SruRecord('991152338469705501', base_url='https://swisscovery.ch/view/sru/41SLSP_NETWORK')
# 2025-09-09 06:24:29,352 - INFO - SruRecord('991152338469705501', base_url='https://swisscovery.ch/view/sru/41SLSP_NETWORK'): record used in IZ: 41SLSP_UZB, 41SLSP_UNE, 41SLSP_RZS, 41SLSP_TRI, 41SLSP_UBS
# 2025-09-09 06:24:29,354 - WARNING - SruRecord('991152338469705501', base_url='https://swisscovery.ch/view/sru/41SLSP_NETWORK') cannot be deleted: record used in IZs: 41SLSP_UZB, 41SLSP_UNE, 41SLSP_RZS, 41SLSP_TRI, 41SLSP_UBS
# 2025-09-09 06:24:29,355 - INFO - SruRecord('991152338469705501', base_url='https://swisscovery.ch/view/sru/41SLSP_NETWORK'): record used in IZ: 41SLSP_UZB, 41SLSP_UNE, 41SLSP_RZS, 41SLSP_TRI, 41SLSP_UBS
# 2025-09-09 06:24:29,358 - INFO - Processed: 7 / remaining: 13 / current: SruRecord('991171357508305501', base_url='https://swisscovery.ch/view/sru/41SLSP_NETWORK')
# 2025-09-09 06:24:29,360 - INFO - SruRecord('991171357508305501', base_url='https://swisscovery.ch/view/sru/41SLSP_NETWORK'): record used in IZ: 41SLSP_UBE
# 2025-09-09 06:24:29,361 - WARNING - SruRecord('991171357508305501', base_url='https://swisscovery.ch/view/sru/41SLSP_NETWORK') cannot be deleted: record used in IZs: 41SLSP_UBE
# 2025-09-09 06:24:29,362 - INFO - SruRecord('991171357508305501', base_url='https://swisscovery.ch/view/sru/41SLSP_NETWORK'): record used in IZ: 41SLSP_UBE
# 2025-09-09 06:24:29,365 - INFO - Processed: 8 / remaining: 12 / current: SruRecord('991126902329705501', base_url='https://swisscovery.ch/view/sru/41SLSP_NETWORK')
# 2025-09-09 06:24:29,366 - INFO - SruRecord('991126902329705501', base_url='https://swisscovery.ch/view/sru/41SLSP_NETWORK'): record not used in the IZs
# 2025-09-09 06:24:30,391 - INFO - SRU data fetched: https://swisscovery.ch/view/sru/41SLSP_NETWORK?query=alma.other_system_number%3D%3D%28RERO%29R233005560-41slsp&version=1.2&operation=searchRetrieve&startRecord=1&maximumRecords=50
# 2025-09-09 06:24:30,397 - INFO - Records 1 - 1 / 1, "alma.other_system_number==(RERO)R233005560-41slsp": 1
# 2025-09-09 06:24:31,540 - INFO - SRU data fetched: https://swisscovery.ch/view/sru/41SLSP_NETWORK?query=alma.other_system_number%3D%3D%28swissbib%29093427611-41slsp_network&version=1.2&operation=searchRetrieve&startRecord=1&maximumRecords=50
# 2025-09-09 06:24:31,545 - INFO - Records 1 - 1 / 1, "alma.other_system_number==(swissbib)093427611-41slsp_network": 1
# 2025-09-09 06:24:32,256 - INFO - SRU data fetched: https://swisscovery.ch/view/sru/41SLSP_NETWORK?query=alma.other_system_number%3D991126902329705501&version=1.2&operation=searchRetrieve&startRecord=1&maximumRecords=50
# 2025-09-09 06:24:32,260 - WARNING - No record found for query alma.other_system_number=991126902329705501
# 2025-09-09 06:24:33,547 - INFO - SRU data fetched: https://swisscovery.ch/view/sru/41SLSP_NETWORK?query=alma.other_system_number_active_035%3D%3D%28RERO%290589406-41slsp&version=1.2&operation=searchRetrieve&startRecord=1&maximumRecords=50
# 2025-09-09 06:24:33,553 - INFO - Records 1 - 1 / 1, "alma.other_system_number_active_035==(RERO)0589406-41slsp": 1
# 2025-09-09 06:24:33,557 - INFO - SruRecord('991070712149705501', base_url='https://swisscovery.ch/view/sru/41SLSP_NETWORK'): record used in IZ: 41SLSP_UGE, 41SLSP_UNE, 41SLSP_SBK, 41SLSP_SUP, 41SLSP_UBE, 41SLSP_BCUFR, 41SLSP_UBS
# 2025-09-09 06:24:33,558 - WARNING - SruRecord('991126902329705501', base_url='https://swisscovery.ch/view/sru/41SLSP_NETWORK') cannot be deleted: record has at least a parent record with inventory: SruRecord('991070712149705501', base_url='https://swisscovery.ch/view/sru/41SLSP_NETWORK') in 41SLSP_UGE, 41SLSP_UNE, 41SLSP_SBK, 41SLSP_SUP, 41SLSP_UBE, 41SLSP_BCUFR, 41SLSP_UBS
# 2025-09-09 06:24:33,559 - INFO - SruRecord('991126902329705501', base_url='https://swisscovery.ch/view/sru/41SLSP_NETWORK'): record not used in the IZs
# 2025-09-09 06:24:33,563 - INFO - Processed: 9 / remaining: 11 / current: SruRecord('991171337525005501', base_url='https://swisscovery.ch/view/sru/41SLSP_NETWORK')
# 2025-09-09 06:24:33,565 - INFO - SruRecord('991171337525005501', base_url='https://swisscovery.ch/view/sru/41SLSP_NETWORK'): record used in IZ: 41SLSP_UZB, 41SLSP_BCUFR
# 2025-09-09 06:24:33,565 - WARNING - SruRecord('991171337525005501', base_url='https://swisscovery.ch/view/sru/41SLSP_NETWORK') cannot be deleted: record used in IZs: 41SLSP_UZB, 41SLSP_BCUFR
# 2025-09-09 06:24:33,567 - INFO - SruRecord('991171337525005501', base_url='https://swisscovery.ch/view/sru/41SLSP_NETWORK'): record used in IZ: 41SLSP_UZB, 41SLSP_BCUFR
# 2025-09-09 06:24:33,570 - INFO - Processed: 10 / remaining: 10 / current: SruRecord('991094843849705501', base_url='https://swisscovery.ch/view/sru/41SLSP_NETWORK')
# 2025-09-09 06:24:33,572 - INFO - SruRecord('991094843849705501', base_url='https://swisscovery.ch/view/sru/41SLSP_NETWORK'): record used in IZ: 41SLSP_ETH, 41SLSP_RZS, 41SLSP_EPF, 41SLSP_BFH
# 2025-09-09 06:24:33,573 - WARNING - SruRecord('991094843849705501', base_url='https://swisscovery.ch/view/sru/41SLSP_NETWORK') cannot be deleted: record used in IZs: 41SLSP_ETH, 41SLSP_RZS, 41SLSP_EPF, 41SLSP_BFH
# 2025-09-09 06:24:33,574 - INFO - SruRecord('991094843849705501', base_url='https://swisscovery.ch/view/sru/41SLSP_NETWORK'): record used in IZ: 41SLSP_ETH, 41SLSP_RZS, 41SLSP_EPF, 41SLSP_BFH
# 2025-09-09 06:24:33,576 - INFO - Processed: 11 / remaining: 9 / current: SruRecord('991093934809705501', base_url='https://swisscovery.ch/view/sru/41SLSP_NETWORK')
# 2025-09-09 06:24:33,578 - INFO - SruRecord('991093934809705501', base_url='https://swisscovery.ch/view/sru/41SLSP_NETWORK'): record used in IZ: 41SLSP_TRI, 41BIG_INST
# 2025-09-09 06:24:33,578 - WARNING - SruRecord('991093934809705501', base_url='https://swisscovery.ch/view/sru/41SLSP_NETWORK') cannot be deleted: record used in IZs: 41SLSP_TRI, 41BIG_INST
# 2025-09-09 06:24:33,579 - INFO - SruRecord('991093934809705501', base_url='https://swisscovery.ch/view/sru/41SLSP_NETWORK'): record used in IZ: 41SLSP_TRI, 41BIG_INST
# 2025-09-09 06:24:33,582 - INFO - Processed: 12 / remaining: 8 / current: SruRecord('991154177219705501', base_url='https://swisscovery.ch/view/sru/41SLSP_NETWORK')
# 2025-09-09 06:24:33,583 - INFO - SruRecord('991154177219705501', base_url='https://swisscovery.ch/view/sru/41SLSP_NETWORK'): record not used in the IZs
# 2025-09-09 06:24:34,467 - INFO - SRU data fetched: https://swisscovery.ch/view/sru/41SLSP_NETWORK?query=alma.other_system_number%3D991154177219705501&version=1.2&operation=searchRetrieve&startRecord=1&maximumRecords=50
# 2025-09-09 06:24:34,474 - WARNING - No record found for query alma.other_system_number=991154177219705501
# 2025-09-09 06:24:35,403 - INFO - SRU data fetched: https://swisscovery.ch/view/sru/41SLSP_NETWORK?query=alma.other_system_number%3D%28IDSSG%29000542807HSB01&version=1.2&operation=searchRetrieve&startRecord=1&maximumRecords=50
# 2025-09-09 06:24:35,411 - INFO - Records 1 - 1 / 1, "alma.other_system_number=(IDSSG)000542807HSB01": 1
# 2025-09-09 06:24:36,714 - INFO - SRU data fetched: https://swisscovery.ch/view/sru/41SLSP_NETWORK?query=alma.other_system_number%3D%3D%28swissbib%29003616487-41slsp_network&version=1.2&operation=searchRetrieve&startRecord=1&maximumRecords=50
# 2025-09-09 06:24:36,718 - INFO - Records 1 - 1 / 1, "alma.other_system_number==(swissbib)003616487-41slsp_network": 1
# 2025-09-09 06:24:37,423 - INFO - SRU data fetched: https://swisscovery.ch/view/sru/41SLSP_NETWORK?query=alma.standard_number%3D9783708907581&version=1.2&operation=searchRetrieve&startRecord=1&maximumRecords=50
# 2025-09-09 06:24:37,428 - INFO - Records 1 - 1 / 1, "alma.standard_number=9783708907581": 1
# 2025-09-09 06:24:37,431 - INFO - SruRecord('991154177219705501', base_url='https://swisscovery.ch/view/sru/41SLSP_NETWORK'): record not used in the IZs
# 2025-09-09 06:24:37,436 - INFO - Processed: 13 / remaining: 7 / current: SruRecord('991156446029705501', base_url='https://swisscovery.ch/view/sru/41SLSP_NETWORK')
# 2025-09-09 06:24:37,439 - INFO - SruRecord('991156446029705501', base_url='https://swisscovery.ch/view/sru/41SLSP_NETWORK'): record not used in the IZs
# 2025-09-09 06:24:38,482 - INFO - SRU data fetched: https://swisscovery.ch/view/sru/41SLSP_NETWORK?query=alma.other_system_number%3D%3D%28swissbib%29093443633-41slsp_network&version=1.2&operation=searchRetrieve&startRecord=1&maximumRecords=50
# 2025-09-09 06:24:38,488 - INFO - Records 1 - 1 / 1, "alma.other_system_number==(swissbib)093443633-41slsp_network": 1
# 2025-09-09 06:24:39,066 - INFO - SRU data fetched: https://swisscovery.ch/view/sru/41SLSP_NETWORK?query=alma.other_system_number%3D991156446029705501&version=1.2&operation=searchRetrieve&startRecord=1&maximumRecords=50
# 2025-09-09 06:24:39,069 - WARNING - No record found for query alma.other_system_number=991156446029705501
# 2025-09-09 06:24:39,700 - INFO - SRU data fetched: https://swisscovery.ch/view/sru/41SLSP_NETWORK?query=alma.other_system_number%3D%3D%28RERO%29R233261160-41slsp&version=1.2&operation=searchRetrieve&startRecord=1&maximumRecords=50
# 2025-09-09 06:24:39,705 - INFO - Records 1 - 1 / 1, "alma.other_system_number==(RERO)R233261160-41slsp": 1
# 2025-09-09 06:24:41,654 - INFO - SRU data fetched: https://swisscovery.ch/view/sru/41SLSP_NETWORK?query=alma.other_system_number_active_035%3D%3D%28RERO%29R233260760-41slsp&version=1.2&operation=searchRetrieve&startRecord=1&maximumRecords=50
# 2025-09-09 06:24:41,661 - INFO - Records 1 - 1 / 1, "alma.other_system_number_active_035==(RERO)R233260760-41slsp": 1
# 2025-09-09 06:24:41,665 - INFO - SruRecord('991072757669705501', base_url='https://swisscovery.ch/view/sru/41SLSP_NETWORK'): record used in IZ: 41SLSP_UZB, 41SLSP_UNE, 41SLSP_UBE, 41SLSP_BCUFR, 41SLSP_VGE, 41SLSP_UBS
# 2025-09-09 06:24:41,666 - WARNING - SruRecord('991156446029705501', base_url='https://swisscovery.ch/view/sru/41SLSP_NETWORK') cannot be deleted: record has at least a parent record with inventory: SruRecord('991072757669705501', base_url='https://swisscovery.ch/view/sru/41SLSP_NETWORK') in 41SLSP_UZB, 41SLSP_UNE, 41SLSP_UBE, 41SLSP_BCUFR, 41SLSP_VGE, 41SLSP_UBS
# 2025-09-09 06:24:41,667 - INFO - SruRecord('991156446029705501', base_url='https://swisscovery.ch/view/sru/41SLSP_NETWORK'): record not used in the IZs
# 2025-09-09 06:24:41,672 - INFO - Processed: 14 / remaining: 6 / current: SruRecord('991170675750105501', base_url='https://swisscovery.ch/view/sru/41SLSP_NETWORK')
# 2025-09-09 06:24:41,673 - INFO - SruRecord('991170675750105501', base_url='https://swisscovery.ch/view/sru/41SLSP_NETWORK'): record not used in the IZs
# 2025-09-09 06:24:42,324 - INFO - SRU data fetched: https://swisscovery.ch/view/sru/41SLSP_NETWORK?query=alma.other_system_number%3D991170675750105501&version=1.2&operation=searchRetrieve&startRecord=1&maximumRecords=50
# 2025-09-09 06:24:42,328 - WARNING - No record found for query alma.other_system_number=991170675750105501
# 2025-09-09 06:24:43,111 - INFO - SRU data fetched: https://swisscovery.ch/view/sru/41SLSP_NETWORK?query=alma.standard_number%3D9780881929843&version=1.2&operation=searchRetrieve&startRecord=1&maximumRecords=50
# 2025-09-09 06:24:43,114 - INFO - Records 1 - 1 / 1, "alma.standard_number=9780881929843": 1
# 2025-09-09 06:24:43,116 - INFO - SruRecord('991170675750105501', base_url='https://swisscovery.ch/view/sru/41SLSP_NETWORK'): record not used in the IZs
# 2025-09-09 06:24:43,119 - INFO - Processed: 15 / remaining: 5 / current: SruRecord('991006488319705501', base_url='https://swisscovery.ch/view/sru/41SLSP_NETWORK')
# 2025-09-09 06:24:43,121 - INFO - SruRecord('991006488319705501', base_url='https://swisscovery.ch/view/sru/41SLSP_NETWORK'): record used in IZ: 41SLSP_UNE, 41SLSP_BCUFR, 41SLSP_VGE
# 2025-09-09 06:24:43,122 - WARNING - SruRecord('991006488319705501', base_url='https://swisscovery.ch/view/sru/41SLSP_NETWORK') cannot be deleted: record used in IZs: 41SLSP_UNE, 41SLSP_BCUFR, 41SLSP_VGE
# 2025-09-09 06:24:43,123 - INFO - SruRecord('991006488319705501', base_url='https://swisscovery.ch/view/sru/41SLSP_NETWORK'): record used in IZ: 41SLSP_UNE, 41SLSP_BCUFR, 41SLSP_VGE
# 2025-09-09 06:24:43,126 - INFO - Processed: 16 / remaining: 4 / current: SruRecord('991153029939705501', base_url='https://swisscovery.ch/view/sru/41SLSP_NETWORK')
# 2025-09-09 06:24:43,127 - INFO - SruRecord('991153029939705501', base_url='https://swisscovery.ch/view/sru/41SLSP_NETWORK'): record used in IZ: 41SLSP_ZAW, 41SLSP_UZB, 41SLSP_FHO, 41SLSP_FNW, 41SLSP_UBE, 41SLSP_RZS, 41SLSP_BCUFR, 41SLSP_UBS
# 2025-09-09 06:24:43,128 - WARNING - SruRecord('991153029939705501', base_url='https://swisscovery.ch/view/sru/41SLSP_NETWORK') cannot be deleted: record used in IZs: 41SLSP_ZAW, 41SLSP_UZB, 41SLSP_FHO, 41SLSP_FNW, 41SLSP_UBE, 41SLSP_RZS, 41SLSP_BCUFR, 41SLSP_UBS
# 2025-09-09 06:24:43,130 - INFO - SruRecord('991153029939705501', base_url='https://swisscovery.ch/view/sru/41SLSP_NETWORK'): record used in IZ: 41SLSP_ZAW, 41SLSP_UZB, 41SLSP_FHO, 41SLSP_FNW, 41SLSP_UBE, 41SLSP_RZS, 41SLSP_BCUFR, 41SLSP_UBS
# 2025-09-09 06:24:43,132 - INFO - Processed: 17 / remaining: 3 / current: SruRecord('991149212459705501', base_url='https://swisscovery.ch/view/sru/41SLSP_NETWORK')
# 2025-09-09 06:24:43,134 - INFO - SruRecord('991149212459705501', base_url='https://swisscovery.ch/view/sru/41SLSP_NETWORK'): record used in IZ: 41SLSP_HSG, 41SLSP_ZAW, 41SLSP_UZB, 41SLSP_ETH, 41SLSP_UBE, 41SLSP_UBS
# 2025-09-09 06:24:43,135 - WARNING - SruRecord('991149212459705501', base_url='https://swisscovery.ch/view/sru/41SLSP_NETWORK') cannot be deleted: record used in IZs: 41SLSP_HSG, 41SLSP_ZAW, 41SLSP_UZB, 41SLSP_ETH, 41SLSP_UBE, 41SLSP_UBS
# 2025-09-09 06:24:43,137 - INFO - SruRecord('991149212459705501', base_url='https://swisscovery.ch/view/sru/41SLSP_NETWORK'): record used in IZ: 41SLSP_HSG, 41SLSP_ZAW, 41SLSP_UZB, 41SLSP_ETH, 41SLSP_UBE, 41SLSP_UBS
# 2025-09-09 06:24:43,140 - INFO - Processed: 18 / remaining: 2 / current: SruRecord('991170647161305501', base_url='https://swisscovery.ch/view/sru/41SLSP_NETWORK')
# 2025-09-09 06:24:43,141 - INFO - SruRecord('991170647161305501', base_url='https://swisscovery.ch/view/sru/41SLSP_NETWORK'): record used in IZ: 41SLSP_HSG, 41SLSP_UZB, 41SLSP_UNE, 41SLSP_SUP, 41SLSP_RZS, 41SLSP_USI, 41SLSP_UBS
# 2025-09-09 06:24:43,142 - WARNING - SruRecord('991170647161305501', base_url='https://swisscovery.ch/view/sru/41SLSP_NETWORK') cannot be deleted: record used in IZs: 41SLSP_HSG, 41SLSP_UZB, 41SLSP_UNE, 41SLSP_SUP, 41SLSP_RZS, 41SLSP_USI, 41SLSP_UBS
# 2025-09-09 06:24:43,144 - INFO - SruRecord('991170647161305501', base_url='https://swisscovery.ch/view/sru/41SLSP_NETWORK'): record used in IZ: 41SLSP_HSG, 41SLSP_UZB, 41SLSP_UNE, 41SLSP_SUP, 41SLSP_RZS, 41SLSP_USI, 41SLSP_UBS
# 2025-09-09 06:24:43,147 - INFO - Processed: 19 / remaining: 1 / current: SruRecord('991171866808105501', base_url='https://swisscovery.ch/view/sru/41SLSP_NETWORK')
# 2025-09-09 06:24:43,148 - INFO - SruRecord('991171866808105501', base_url='https://swisscovery.ch/view/sru/41SLSP_NETWORK'): record used in IZ: 41SLSP_UZB, 41SLSP_RZS
# 2025-09-09 06:24:43,149 - WARNING - SruRecord('991171866808105501', base_url='https://swisscovery.ch/view/sru/41SLSP_NETWORK') cannot be deleted: record used in IZs: 41SLSP_UZB, 41SLSP_RZS
# 2025-09-09 06:24:43,151 - INFO - SruRecord('991171866808105501', base_url='https://swisscovery.ch/view/sru/41SLSP_NETWORK'): record used in IZ: 41SLSP_UZB, 41SLSP_RZS
# 2025-09-09 06:24:43,154 - INFO - Processed: 20 / remaining: 0 / current: SruRecord('991055945739705501', base_url='https://swisscovery.ch/view/sru/41SLSP_NETWORK')
# 2025-09-09 06:24:43,155 - INFO - SruRecord('991055945739705501', base_url='https://swisscovery.ch/view/sru/41SLSP_NETWORK'): record used in IZ: 41SLSP_RZS
# 2025-09-09 06:24:43,156 - WARNING - SruRecord('991055945739705501', base_url='https://swisscovery.ch/view/sru/41SLSP_NETWORK') cannot be deleted: record used in IZs: 41SLSP_RZS
# 2025-09-09 06:24:43,157 - INFO - SruRecord('991055945739705501', base_url='https://swisscovery.ch/view/sru/41SLSP_NETWORK'): record used in IZ: 41SLSP_RZS
#                     removable                         comment bib_level  \
# mms_id
# 991171228773105501       True                       REMOVABLE         m
# 991153648929705501       True                       REMOVABLE         m
# 991095338679705501      False  Record used in at least one IZ         m
# 991108597099705501      False  Record used in at least one IZ         m
# 991107511699705501      False  Record used in at least one IZ         s
# 991132863209705501       True                       REMOVABLE         m
# 991152338469705501      False  Record used in at least one IZ         m
# 991171357508305501      False  Record used in at least one IZ         m
# 991126902329705501      False     Parent record has inventory         a
# 991171337525005501      False  Record used in at least one IZ         m
# 991094843849705501      False  Record used in at least one IZ         m
# 991093934809705501      False  Record used in at least one IZ         a
# 991154177219705501       True                       REMOVABLE         m
# 991156446029705501      False     Parent record has inventory         a
# 991170675750105501       True                       REMOVABLE         m
# 991006488319705501      False  Record used in at least one IZ         m
# 991153029939705501      False  Record used in at least one IZ         m
# 991149212459705501      False  Record used in at least one IZ         m
# 991170647161305501      False  Record used in at least one IZ         m
# 991171866808105501      False  Record used in at least one IZ         m
# 991055945739705501      False  Record used in at least one IZ         m
#
#                                                     IZ_with_inventory  \
# mms_id
# 991171228773105501
# 991153648929705501
# 991095338679705501                              41SLSP_ETH|41SLSP_EPF
# 991108597099705501                                         41SLSP_SUP
# 991107511699705501                   41SLSP_RZH|41SLSP_VGE|41SLSP_UBS
# 991132863209705501
# 991152338469705501  41SLSP_UZB|41SLSP_UNE|41SLSP_RZS|41SLSP_TRI|41...
# 991171357508305501                                         41SLSP_UBE
# 991126902329705501
# 991171337525005501                            41SLSP_UZB|41SLSP_BCUFR
# 991094843849705501        41SLSP_ETH|41SLSP_RZS|41SLSP_EPF|41SLSP_BFH
# 991093934809705501                              41SLSP_TRI|41BIG_INST
# 991154177219705501
# 991156446029705501
# 991170675750105501
# 991006488319705501                 41SLSP_UNE|41SLSP_BCUFR|41SLSP_VGE
# 991153029939705501  41SLSP_ZAW|41SLSP_UZB|41SLSP_FHO|41SLSP_FNW|41...
# 991149212459705501  41SLSP_HSG|41SLSP_ZAW|41SLSP_UZB|41SLSP_ETH|41...
# 991170647161305501  41SLSP_HSG|41SLSP_UZB|41SLSP_UNE|41SLSP_SUP|41...
# 991171866808105501                              41SLSP_UZB|41SLSP_RZS
# 991055945739705501                                         41SLSP_RZS
#
#                    child_records      parent_records  fields_to_check  \
# mms_id
# 991171228773105501                                                NaN
# 991153648929705501                                                NaN
# 991095338679705501                                                NaN
# 991108597099705501                                                NaN
# 991107511699705501                                                NaN
# 991132863209705501                                                NaN
# 991152338469705501                                                NaN
# 991171357508305501                                                NaN
# 991126902329705501                991070712149705501              NaN
# 991171337525005501                                                NaN
# 991094843849705501                                                NaN
# 991093934809705501                                                NaN
# 991154177219705501                                                NaN
# 991156446029705501                991072757669705501              NaN
# 991170675750105501                                                NaN
# 991006488319705501                                                NaN
# 991153029939705501                                                NaN
# 991149212459705501                                                NaN
# 991170647161305501                                                NaN
# 991171866808105501                                                NaN
# 991055945739705501                                                NaN
#
#                     warning  error  additional_mms_id
# mms_id
# 991171228773105501      NaN  False              False
# 991153648929705501      NaN  False              False
# 991095338679705501      NaN  False              False
# 991108597099705501      NaN  False              False
# 991107511699705501      NaN  False              False
# 991132863209705501      NaN  False              False
# 991152338469705501      NaN  False              False
# 991171357508305501      NaN  False              False
# 991126902329705501      NaN  False              False
# 991171337525005501      NaN  False              False
# 991094843849705501      NaN  False              False
# 991093934809705501      NaN  False              False
# 991154177219705501      NaN  False              False
# 991156446029705501      NaN  False              False
# 991170675750105501      NaN  False              False
# 991006488319705501      NaN  False              False
# 991153029939705501      NaN  False              False
# 991149212459705501      NaN  False              False
# 991170647161305501      NaN  False              False
# 991171866808105501      NaN  False              False
# 991055945739705501      NaN  False              False

# %% [markdown]
# ## Part 5: projects - Check inventory of libraries

# %%
# Import libraries
from almasru.client import SruClient, SruRecord, IzSruRecord, SruRequest
from almasru.utils import check_removable_records, analyse_records
from almasru import dedup
from almasru.briefrecord import BriefRecFactory, BriefRec
from almasru import config_log
from lxml import etree

parser = etree.XMLParser(remove_blank_text=True, remove_comments=True, ns_clean=True)

ns = {
    "srw": "http://www.loc.gov/zing/srw/",
    "marc": "http://www.loc.gov/MARC21/slim"
}

# Config logs
config_log()
zone = '41SLSP_NETWORK'
SruClient.set_base_url(f'https://swisscovery.ch/view/sru/{zone}')
std_num = '0020-7985'
records = SruRequest(f'alma.standard_number={std_num}').records

def has_record_std_num_in_02x(std_num, record):
    std_nums = [f.text.replace('-', '') for f in record.data.findall('.//marc:datafield[@tag="020"]/marc:subfield[@code="a"]', namespaces=ns)]
    std_nums += [f.text.replace('-', '') for f in record.data.findall('.//marc:datafield[@tag="022"]/marc:subfield[@code="a"]', namespaces=ns)]
    if std_num.replace('-', '') in std_nums:
        return True
    else:
        return False

records = [r for r in records if has_record_std_num_in_02x(std_num, r)]

result = dict()
for record in records:
    izs = record.get_iz_using_rec()
    for iz in izs:
        result[iz] = set()
        iz_rec = record.get_iz_record(f'https://swisscovery.ch/view/sru/{iz}')
        inventory = iz_rec.get_inventory_info()
        for hol in inventory:
            result[iz].add(hol['library'])
            
result
# Out:
# 2025-09-09 06:24:45,324 - INFO - SRU data fetched: https://swisscovery.ch/view/sru/41SLSP_NETWORK?query=alma.standard_number%3D0020-7985&version=1.2&operation=searchRetrieve&startRecord=1&maximumRecords=10
# 2025-09-09 06:24:45,332 - INFO - Records 1 - 9 / 9, "alma.standard_number=0020-7985": 9
# 2025-09-09 06:24:45,339 - INFO - SruRecord('991170911588205501', base_url='https://swisscovery.ch/view/sru/41SLSP_NETWORK'): record used in IZ: 41BIG_INST
# 2025-09-09 06:24:45,342 - INFO - SruRecord('991170911588205501', base_url='https://swisscovery.ch/view/sru/41SLSP_NETWORK'): 1 records in IZ found
# 2025-09-09 06:24:46,839 - INFO - SRU data fetched: https://swisscovery.ch/view/sru/41BIG_INST?query=alma.mms_id%3D993900804101791&version=1.2&operation=searchRetrieve&startRecord=1&maximumRecords=10
# 2025-09-09 06:24:46,847 - INFO - Records 1 - 1 / 1, "alma.mms_id=993900804101791": 1
# 2025-09-09 06:24:46,850 - INFO - IzSruRecord('993900804101791', base_url='https://swisscovery.ch/view/sru/41BIG_INST'): inventory in IZ found (2)
# 2025-09-09 06:24:46,854 - INFO - SruRecord('991124328919705501', base_url='https://swisscovery.ch/view/sru/41SLSP_NETWORK'): record used in IZ: 41SLSP_RZH, 41SLSP_SBK, 41SLSP_UBS
# 2025-09-09 06:24:46,857 - INFO - SruRecord('991124328919705501', base_url='https://swisscovery.ch/view/sru/41SLSP_NETWORK'): 3 records in IZ found
# 2025-09-09 06:24:46,860 - INFO - IzSruRecord('990009912310205526', base_url='https://swisscovery.ch/view/sru/41SLSP_RZH'): inventory in IZ found (2)
# 2025-09-09 06:24:46,862 - INFO - SruRecord('991124328919705501', base_url='https://swisscovery.ch/view/sru/41SLSP_NETWORK'): 3 records in IZ found
# 2025-09-09 06:24:47,917 - INFO - SRU data fetched: https://swisscovery.ch/view/sru/41SLSP_SBK?query=alma.mms_id%3D990009912310205526&version=1.2&operation=searchRetrieve&startRecord=1&maximumRecords=10
# 2025-09-09 06:24:47,924 - WARNING - No record found for query alma.mms_id=990009912310205526
# 2025-09-09 06:24:47,926 - ERROR - IzSruRecord('990009912310205526', base_url='https://swisscovery.ch/view/sru/41SLSP_SBK'): number of records found: 0, should be only 1
# 2025-09-09 06:24:49,155 - INFO - SRU data fetched: https://swisscovery.ch/view/sru/41SLSP_SBK?query=alma.mms_id%3D990009912310205529&version=1.2&operation=searchRetrieve&startRecord=1&maximumRecords=10
# 2025-09-09 06:24
version=1.2&operation=searchRetrieve&startRecord=1&maximumRecords=10
# 2025-09-09 06:25:07,483 - INFO - Records 1 - 1 / 1, "alma.mms_id=991007629319705509": 1
# 2025-09-09 06:25:07,487 - INFO - IzSruRecord('991007629319705509', base_url='https://swisscovery.ch/view/sru/41SLSP_BCUFR'): inventory in IZ found (1)
# 2025-09-09 06:25:07,488 - INFO - SruRecord('991002592419705501', base_url='https://swisscovery.ch/view/sru/41SLSP_NETWORK'): 5 records in IZ found
# 2025-09-09 06:25:08,161 - INFO - SRU data fetched: https://swisscovery.ch/view/sru/41SLSP_IID?query=alma.mms_id%3D991009361719705502&version=1.2&operation=searchRetrieve&startRecord=1&maximumRecords=10
# 2025-09-09 06:25:08,169 - WARNING - No record found for query alma.mms_id=991009361719705502
# 2025-09-09 06:25:08,170 - ERROR - IzSruRecord('991009361719705502', base_url='https://swisscovery.ch/view/sru/41SLSP_IID'): number of records found: 0, should be only 1
# 2025-09-09 06:25:09,026 - INFO - SRU data fetched: https://swisscovery.ch/view/sru/41SLSP_IID?query=alma.mms_id%3D991004434529705517&version=1.2&operation=searchRetrieve&startRecord=1&maximumRecords=10
# 2025-09-09 06:25:09,032 - WARNING - No record found for query alma.mms_id=991004434529705517
# 2025-09-09 06:25:09,034 - ERROR - IzSruRecord('991004434529705517', base_url='https://swisscovery.ch/view/sru/41SLSP_IID'): number of records found: 0, should be only 1
# 2025-09-09 06:25:09,769 - INFO - SRU data fetched: https://swisscovery.ch/view/sru/41SLSP_IID?query=alma.mms_id%3D991007629319705509&version=1.2&operation=searchRetrieve&startRecord=1&maximumRecords=10
# 2025-09-09 06:25:09,774 - WARNING - No record found for query alma.mms_id=991007629319705509
# 2025-09-09 06:25:09,776 - ERROR - IzSruRecord('991007629319705509', base_url='https://swisscovery.ch/view/sru/41SLSP_IID'): number of records found: 0, should be only 1
# 2025-09-09 06:25:10,525 - INFO - SRU data fetched: https://swisscovery.ch/view/sru/41SLSP_IID?query=alma.mms_id%3D991001582929705523&version=1.2&operation=searchRetrieve&startRecord=1&maximumRecords=10
# 2025-09-09 06:25:10,533 - INFO - Records 1 - 1 / 1, "alma.mms_id=991001582929705523": 1
# 2025-09-09 06:25:10,536 - INFO - IzSruRecord('991001582929705523', base_url='https://swisscovery.ch/view/sru/41SLSP_IID'): inventory in IZ found (1)
# 2025-09-09 06:25:10,538 - INFO - SruRecord('991002592419705501', base_url='https://swisscovery.ch/view/sru/41SLSP_NETWORK'): 5 records in IZ found
# 2025-09-09 06:25:11,337 - INFO - SRU data fetched: https://swisscovery.ch/view/sru/41SLSP_VGE?query=alma.mms_id%3D991009361719705502&version=1.2&operation=searchRetrieve&startRecord=1&maximumRecords=10
# 2025-09-09 06:25:11,343 - WARNING - No record found for query alma.mms_id=991009361719705502
# 2025-09-09 06:25:11,345 - ERROR - IzSruRecord('991009361719705502', base_url='https://swisscovery.ch/view/sru/41SLSP_VGE'): number of records found: 0, should be only 1
# 2025-09-09 06:25:12,213 - INFO - SRU data fetched: https://swisscovery.ch/view/sru/41SLSP_VGE?query=alma.mms_id%3D991004434529705517&version=1.2&operation=searchRetrieve&startRecord=1&maximumRecords=10
# 2025-09-09 06:25:12,217 - WARNING - No record found for query alma.mms_id=991004434529705517
# 2025-09-09 06:25:12,219 - ERROR - IzSruRecord('991004434529705517', base_url='https://swisscovery.ch/view/sru/41SLSP_VGE'): number of records found: 0, should be only 1
# 2025-09-09 06:25:12,788 - INFO - SRU data fetched: https://swisscovery.ch/view/sru/41SLSP_VGE?query=alma.mms_id%3D991007629319705509&version=1.2&operation=searchRetrieve&startRecord=1&maximumRecords=10
# 2025-09-09 06:25:12,794 - WARNING - No record found for query alma.mms_id=991007629319705509
# 2025-09-09 06:25:12,796 - ERROR - IzSruRecord('991007629319705509', base_url='https://swisscovery.ch/view/sru/41SLSP_VGE'): number of records found: 0, should be only 1
# 2025-09-09 06:25:13,458 - INFO - SRU data fetched: https://swisscovery.ch/view/sru/41SLSP_VGE?query=alma.mms_id%3D991001582929705523&version=1.2&operation=searchRetrieve&startRecord=1&maximumRecords=10
# 2025-09-09 06:25:13,463 - WARNING - No record found for query alma.mms_id=991001582929705523
# 2025-09-09 06:25:13,465 - ERROR - IzSruRecord('991001582929705523', base_url='https://swisscovery.ch/view/sru/41SLSP_VGE'): number of records found: 0, should be only 1
# 2025-09-09 06:25:14,253 - INFO - SRU data fetched: https://swisscovery.ch/view/sru/41SLSP_VGE?query=alma.mms_id%3D991005434789705524&version=1.2&operation=searchRetrieve&startRecord=1&maximumRecords=10
# 2025-09-09 06:25:14,259 - INFO - Records 1 - 1 / 1, "alma.mms_id=991005434789705524": 1
# 2025-09-09 06:25:14,260 - INFO - IzSruRecord('991005434789705524', base_url='https://swisscovery.ch/view/sru/41SLSP_VGE'): inventory in IZ found (1)
# {'41BIG_INST': {'BIG'},
#  '41SLSP_RZH': {'E19'},
#  '41SLSP_SBK': {'UZSBK', 'Z0SBK'},
#  '41SLSP_UBS': {'A125'},
#  '41SLSP_UGE': {'uge_mail'},
#  '41SLSP_UNE': {'une_sfm'},
#  '41SLSP_IID': {'iid'},
#  '41SLSP_VGE': {'vge_bge'},
#  '41SLSP_BCUFR': {'BCUF_BP2'}}

# %% [markdown]
# ## Part 5: projects - Deduplication

# %%
# Import libraries
from dedupmarcxml.evaluate import evaluate_records_similarity, get_similarity_score
from dedupmarcxml.briefrecord import XmlBriefRec
# Out:
# C:\Users\RaphaëlRey\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\sklearn\base.py:442: InconsistentVersionWarning: Trying to unpickle estimator DecisionTreeClassifier from version 1.6.1 when using version 1.7.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# C:\Users\RaphaëlRey\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\sklearn\base.py:442: InconsistentVersionWarning: Trying to unpickle estimator RandomForestClassifier from version 1.6.1 when using version 1.7.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# C:\Users\RaphaëlRey\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\sklearn\base.py:442: InconsistentVersionWarning: Trying to unpickle estimator LabelBinarizer from version 1.6.1 when using version 1.7.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# C:\Users\RaphaëlRey\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\sklearn\base.py:442: InconsistentVersionWarning: Trying to unpickle estimator MLPClassifier from version 1.6.1 when using version 1.7.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
def is_duplicated(rec1: XmlBriefRec, rec2: XmlBriefRec) -> Tuple[bool, float]:
    """
    Determine whether two MARC XML records are considered duplicates.

    Parameters
    ----------
    rec1 : XmlBriefRec
        First record, constructed from an etree.Element representing a MARC XML record.
    rec2 : XmlBriefRec
        Second record to compare, also constructed from an etree.Element.

    Returns
    -------
    Tuple[bool, float]
        A tuple containing:
        - A boolean indicating whether the records are considered duplicates.
        - A float representing the similarity score (≥ 0.5 indicates duplication).
    """
    score_detailed = evaluate_records_similarity(rec1, rec2)
    return get_similarity_score(score_detailed, method='random_forest_general') >= 0.5, get_similarity_score(score_detailed, method='random_forest_general')

# %%
# Same material type (ISBN: 9782412077467)
SruClient.set_base_url('https://renouvaud.primo.exlibrisgroup.com/view/sru/41BCULAUSA_NETWORK')
r = SruRequest(query='alma.mms_id=991024372153702851')
bcul_rec = r.records[0] 
bcul_briefrec = XmlBriefRec(bcul_rec.data)
SruClient.set_base_url('https://swisscovery.ch/view/sru/41SLSP_NETWORK')
r = SruRequest(query='alma.mms_id=991171135496005501')
slsp_rec = r.records[0] 
slsp_briefrec = XmlBriefRec(slsp_rec.data)
result, score = is_duplicated(slsp_briefrec, bcul_briefrec)
print(f'Is duplicated: {result} ({score})')
# Out:
# 2025-09-09 06:25:16,396 - INFO - Records 1 - 1 / 1, "alma.mms_id=991024372153702851": 1
# 2025-09-09 06:25:16,406 - INFO - Records 1 - 1 / 1, "alma.mms_id=991171135496005501": 1
# Is duplicated: True (0.8056666666666668)

# %%
# Print compared to e-version (ISBN: 9782412077467)
SruClient.set_base_url('https://renouvaud.primo.exlibrisgroup.com/view/sru/41BCULAUSA_NETWORK')
r = SruRequest(query='alma.mms_id=991024372153702851')
bcul_rec = r.records[0] 
bcul_briefrec = XmlBriefRec(bcul_rec.data)
SruClient.set_base_url('https://swisscovery.ch/view/sru/41SLSP_NETWORK')
r = SruRequest(query='alma.mms_id=991171940910205501')
slsp_rec = r.records[0] 
slsp_briefrec = XmlBriefRec(slsp_rec.data)
result, score = is_duplicated(slsp_briefrec, bcul_briefrec)
print(f'Is duplicated: {result} ({score})')
# Out:
# 2025-09-09 06:25:16,436 - INFO - Records 1 - 1 / 1, "alma.mms_id=991024372153702851": 1
# 2025-09-09 06:25:16,442 - INFO - Records 1 - 1 / 1, "alma.mms_id=991171940910205501": 1
# Is duplicated: False (0.3653333333333333)

# %%
print(bcul_briefrec)
# Out:
# {
#     "rec_id": "991024372153702851",
#     "format": {
#         "type": "Book",
#         "access": "Physical",
#         "analytical": false,
#         "f33x": "txt;n;nc"
#     },
#     "titles": [
#         {
#             "m": "Python pour la finance :",
#             "s": "ma\u00eetriser la finance algorithmique /"
#         }
#     ],
#     "short_titles": [
#         "Python pour la finance :"
#     ],
#     "creators": [
#         "Hilpisch, Yves"
#     ],
#     "corp_creators": null,
#     "languages": [
#         "fre"
#     ],
#     "extent": {
#         "nb": [
#             689,
#             23
#         ],
#         "txt": "xxiii, 689 pages :"
#     },
#     "editions": null,
#     "years": {
#         "y1": [
#             2022
#         ],
#         "y2": 2024
#     },
#     "publishers": [
#         "First Interactive,",
#         "O'Reilly"
#     ],
#     "series": null,
#     "parent": null,
#     "std_nums": [
#         "9782412077467"
#     ],
#     "sys_nums": [
#         "(RNV_B)0003003761"
#     ]
# }

# %%
print(slsp_briefrec)
# Out:
# {
#     "rec_id": "991171940910205501",
#     "format": {
#         "type": "Book",
#         "access": "Online",
#         "analytical": false,
#         "f33x": "txt;c;cr"
#     },
#     "titles": [
#         {
#             "m": "Python pour la finance /",
#             "s": ""
#         }
#     ],
#     "short_titles": [
#         "Python pour la finance /"
#     ],
#     "creators": [
#         "Hilpisch, Yves J.,",
#         "Engler, Olivier,"
#     ],
#     "corp_creators": null,
#     "languages": [
#         "fre"
#     ],
#     "extent": {
#         "nb": [
#             689,
#             1
#         ],
#         "txt": "1 online resource (689 pages) :"
#     },
#     "editions": [
#         {
#             "nb": [
#                 2
#             ],
#             "txt": "Second edition."
#         }
#     ],
#     "years": {
#         "y1": [
#             2022
#         ]
#     },
#     "publishers": [
#         "E\u0301ditions First,"
#     ],
#     "series": null,
#     "parent": null,
#     "std_nums": [
#         "2412077460",
#         "9782412077467"
#     ],
#     "sys_nums": [
#         "(CaSebORM)9782412077467",
#         "(CKB)36003511800041",
#         "(OCoLC)1456120331",
#         "(OCoLC-P)1456120331",
#         "(EXLCZ)9936003511800041"
#     ]
# }

# %%
def get_ldr_6_and_7_req(document_type: str) -> str:
    """Convert document type of short records into the original value
    of the leader field position 6 and 7. It returns the SRU request arguments
    to filter the results acording to the leader."""
    if document_type is None:
        return ''
    
    return f'%20and%20alma.type_of_record={document_type[0]}%20and%20alma.bib_level={document_type[1]}'

def get_requests(rec: BriefRec) -> Dict:
    """Create a list of arguments for SRU requests. Requests are grouped in
    two lists: "simple" and "extended". Idea is to use "extended" requests
    only when no match is found with "simple" requests."""
    
    # Create lists of requests
    reqs = {'simple': [],
            'extended': []}
    
    # Short title is used in various requests
    short_title = f'alma.title="{rec.data["titles"][0]["s"]}"'
    
    # isbn requests
    if rec.data['std_nums']:
        for isbn in rec.data['std_nums']:
            reqs['simple'].append(f'alma.isbn={isbn}')
    
    # issn requests
    if rec.data['std_nums']:
        for issn in rec.data['std_nums']:
            reqs['simple'].append(f'alma.issn={issn}')
    
    # sysnums
    if rec.data['sys_nums'] is not None:
        for sysnum in rec.data['sys_nums']:
            reqs['simple'].append(f'alma.other_system_number={sysnum}')
    
    # title
    reqs['simple'].append(f'alma.title="{rec.data["titles"][0]["m"]}"')

    # add filter on the format for each request
    reqs['simple'] = [req + get_ldr_6_and_7_req('am') for req in reqs['simple']]
    reqs['simple'] = [req + '%20and%20alma.is_linked==0' for req in reqs['simple']]
    
    # short title + creator
    if rec.data['creators'] is not None:
        for creator in rec.data['creators']:
            simple_creator = creator.split(',')[0].strip()
            reqs['extended'].append(f'{short_title}%20and%20alma.creator="{simple_creator}"')
    
    # short title + organisation
    if rec.data['corp_creators'] is not None:
        for creator in rec.data['corp_creators']:
            reqs['extended'].append(f'{short_title}%20and%20alma.creator="{creator}"')
    
    # date + creator
    if rec.data['years'] is not None and rec.data['years']['y1'] is not None and rec.data['creators'] is not None:
        pub_date = str(rec.data['years']['y1'][0])
        for creator in rec.data['creators']:
            simple_creator = creator.split(',')[0].strip()
            reqs['extended'].append(f'alma.main_pub_date={pub_date}%20and%20alma.creator="{simple_creator}"')
    
    # date + organisation
    if rec.data['years'] is not None and rec.data['years']['y1'] is not None and rec.data['corp_creators'] is not None:
        date_1 = str(rec.data['years']['y1'][0])
        for creator in rec.data['corp_creators']:
            reqs['extended'].append(f'alma.main_pub_date={date_1}%20and%20alma.creator="{creator}"')
    
    # short title
    reqs['extended'].append(short_title)
    
    # general keywords
    if rec.data['years'] is not None and rec.data['years']['y1'] is not None:
        date_1 = str(rec.data['years']['y1'][0])
        reqs['extended'].append(f'alma.all_for_ui="{short_title}"%20and%20alma.all_for_ui={date_1}"')
    
    # add filter on the format for each request
    reqs['extended'] = [req + get_ldr_6_and_7_req('am') for req in reqs['extended']]
    reqs['extended'] = [req + '%20and%20alma.is_linked==0' for req in reqs['extended']]
    
    return reqs


def get_records_from_requests(reqs: List[str], limit: int) -> Set['BriefRec']:
    """Use the provided list of requests to fetch records
    on the SRU server. Transform the results in `BriefRec`
    records.
    """
    records = set()
    
    for req in reqs:
        r = SruClient().fetch_records(req, limit)
        records = records.union(r.records)

    records = {XmlBriefRec(rec.data) for rec in records}
    return records

# %%
SruClient.set_base_url('https://renouvaud.primo.exlibrisgroup.com/view/sru/41BCULAUSA_NETWORK')
r = SruRequest(query='alma.isbn=9782412077467')
bcul_rec = r.records[0]
bcul_rec.mms_id
# Out:
# 2025-09-09 06:25:16,521 - INFO - Records 1 - 1 / 1, "alma.isbn=9782412077467": 1
# '991024372153702851'

# %%
def fetch_duplicated_in_slsp(mms_id: str) -> Tuple[bool, Optional[str], float]:
    """Check if duplicated records are available in SLSP NZ

    Parameter:
    ----------
    mms_id: str containing the mms_id of the Renouvaud record

    Returns:
    --------
    Tuple containing the result of the evaluation
    """
    SruClient.set_base_url('https://renouvaud.primo.exlibrisgroup.com/view/sru/41BCULAUSA_NETWORK')
    bcul_rec = SruRecord(mms_id)
    bcul_briefrec = XmlBriefRec(bcul_rec.data)
    SruClient.set_base_url('https://swisscovery.ch/view/sru/41SLSP_NETWORK')
    reqs = get_requests(bcul_briefrec)
    records_to_compare = get_records_from_requests(reqs['simple'], limit=500)

    duplicated = False
    slsp_mms_id = None
    max_score = 0
    for record in records_to_compare:
        result, score = is_duplicated(bcul_briefrec, record)
        if score >= max_score:
            slsp_mms_id = record.data['rec_id']
            max_score = score
            if max_score >= 0.5:
                duplicated = True
    return (duplicated, slsp_mms_id, max_score)

bcul_mms_id = '991024372153702851'
fetch_duplicated_in_slsp(bcul_mms_id)
# Out:
# (True, '991171135496005501', np.float64(0.8056666666666668))
